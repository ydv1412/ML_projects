# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
from torchvision import models
from torchvision import transforms
import cv2
from PIL import Image
from torchvision.datasets.utils import download_url
import torch
import json

# %%
alexnet = models.AlexNet()         #### alexnet is an articeture

# %%
resnet = models.resnet101(pretrained = True)                #### resnet is an pretrained 101 layer nural network
# Out:
# Downloading: "https://download.pytorch.org/models/resnet101-5d3b4d8f.pth" to /root/.cache/torch/hub/checkpoints/resnet101-5d3b4d8f.pth
# ...

# %%
preprocess = transforms.Compose([transforms.Resize(256) , transforms.CenterCrop(224) , transforms.ToTensor() , transforms.Normalize(mean = [0.485 , 0.456 , 0.406] , std = [0.229 , 0.224 , 0.225])])

# %%
#### before classification we have to first process our image ,here resize () scales our image to 256*256 ,normalize() normalizes the red green and blue colours

# %%
type(image)
# Out:
# NoneType

# %%
import os

# %%
os.getcwd()
# Out:
# '/content'

# %%
os.listdir()
# Out:
# ['.config', 'gdrive', 'sample_data']

# %%
os.chdir('gdrive')

# %%
os.listdir()
# Out:
# ['.file-revisions-by-id', '.shortcut-targets-by-id', 'MyDrive', '.Trash']

# %%
os.chdir('MyDrive')

# %%
os.listdir()
# Out:
# ['9004342_Confirmation.pdf',
#  'ip_windows_64_ver1.zip',
#  'caste.pdf',
#  'ip_windows_64_ver1.zip (Unzipped Files) (1)',
#  'ip_windows_64_ver1.zip (Unzipped Files)',
#  'Classroom',
#  'Ravi cv 2020.pdf',
#  'java assignment 00410107219 shri prakash yadav.pdf',
#  'student identity card.pdf',
#  'Untitled document (1).gdoc',
#  'Untitled document.gdoc',
#  '00410107219 shri prakash yadav....rtf',
#  'introduction..shri prakash yadav 00410107219.mp3',
#  'tmp_pic_1614599301267.png',
#  'tmp_pic_1614599458514.png',
#  'Colab Notebooks',
#  'meshgrid_image.png',
#  'jre-8u281-windows-x64.exe',
#  'mnist',
#  'amazon_fine_food',
#  'data_sets_for_knn',
#  'archive',
#  'web_scrapping',
#  'open_cv',
#  'mini_projects']

# %%
os.chdir('mini_projects')

# %%
image = Image.open("dog.jpg")

# %%
image
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
img_t = preprocess(image)

# %%
batch_t = torch.unsqueeze(img_t, 0 )                 ### return a tensor of 0 dimension
resnet.eval()                                               ### putting network in evaluation mode
out = resnet(batch_t)
out
# Out:
# tensor([[-3.9066e+00, -1.7903e+00, -1.7339e+00, -4.9584e+00, -2.6453e+00,
#          -1.7054e+00, -2.1441e+00,  1.0132e+00,  1.5163e+00, -3.1924e+00,
#          -5.6319e-01, -1.8288e+00, -2.1742e+00, -2.7725e-02, -1.1065e+00,
#          -2.4111e-01, -4.0117e-01,  1.0394e+00, -1.1994e+00,  5.1383e-01,
#          -1.0925e+00, -1.7986e+00, -2.8298e+00, -1.8253e+00, -1.1406e+00,
#          -1.3778e+00, -1.0533e+00,  2.6927e-02, -5.6745e-01, -7.4053e-01,
#          -3.0931e+00, -1.1147e+00, -1.3931e+00, -2.2016e+00, -1.5350e+00,
#          -2.5354e-01,  6.3006e-01,  1.0970e+00, -5.3802e-02, -1.0538e+00,
#          -3.7726e-01, -9.0249e-02, -1.1505e+00, -1.1427e+00,  6.9809e-01,
#           2.6182e-02, -2.3145e-01, -2.9116e+00, -3.3515e-01, -2.0027e+00,
#          -2.4084e+00,  3.0221e-01,  8.6826e-01, -8.6030e-01, -1.8907e+00,
#           2.1106e-01,  1.3850e+00, -7.9710e-01, -5.1467e-01, -1.2412e+00,
#          -2.7168e-01, -1.5965e+00, -5.8257e-01, -4.9642e-01, -1.6774e+00,
# ...

# %%
download_url("https://s3.amazonaws.com/deep-learning-models/image-models/imagenet_class_index.json", ".", "imagenet_class_index.json")

# %%
with open("imagenet_class_index.json", "r")  as f:
  labels = json.load(f)
  
###imagenet_class_index.json contains class labels

# %%
_ ,index = torch.max(out , 1)

# %%
label_indices = out.argmax(dim=1)
for p in label_indices:
    print(labels[str(p.item())])
# Out:
# ['n02098413', 'Lhasa']
